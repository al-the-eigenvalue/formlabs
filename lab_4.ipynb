# %%
# %%capture
# !pip install corus nerus razdel sklearn_crfsuite

# %%
import re

from itertools import islice
from nerus import load_nerus
from razdel import tokenize
from tqdm.autonotebook import tqdm
from sklearn_crfsuite import CRF, metrics
from sklearn.model_selection import train_test_split
# Out:
# /tmp/ipython-input-3775069905.py:6: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
# !wget https://storage.yandexcloud.net/natasha-nerus/data/nerus_lenta.conllu.gz
# Out:
# --2025-09-06 11:41:28--  https://storage.yandexcloud.net/natasha-nerus/data/nerus_lenta.conllu.gz
# Resolving storage.yandexcloud.net (storage.yandexcloud.net)... 213.180.193.243, 2a02:6b8::1d9
# Connecting to storage.yandexcloud.net (storage.yandexcloud.net)|213.180.193.243|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1961465886 (1.8G) [application/octet-stream]
# Saving to: ‘nerus_lenta.conllu.gz’
#
# nerus_lenta.conllu. 100%[===================>]   1.83G  23.3MB/s    in 85s
#
# 2025-09-06 11:42:54 (22.0 MB/s) - ‘nerus_lenta.conllu.gz’ saved [1961465886/1961465886]

# %% [markdown]
# ### Загрузка корпуса

# %%
num_docs = 2000

docs = list(
    tqdm(
        islice(load_nerus("nerus_lenta.conllu.gz"), num_docs),
        total=num_docs,
        desc="Loading Nerus"
    )
)

print(f"Loaded {len(docs)} documents")
# Out:
# Loading Nerus:   0%|          | 0/2000 [00:00<?, ?it/s]
# Loaded 2000 documents

# %%
def doc_to_data(doc):
    X, y = [], []
    for sent in doc.sents:
        tokens, labels = [], []
        for token in sent.tokens:
            tokens.append(token.text)
            labels.append(token.pos)
        X.append(tokens)
        y.append(labels)
    return X, y

# %%
doc_example = doc_to_data(docs[0])

sent_example = doc_example[0][0]
labels_example = doc_example[1][0]

print("Пример предложения:", sent_example)
print("Разметка:", labels_example)
# Out:
# Пример предложения: ['Вице-премьер', 'по', 'социальным', 'вопросам', 'Татьяна', 'Голикова', 'рассказала', ',', 'в', 'каких', 'регионах', 'России', 'зафиксирована', 'наиболее', 'высокая', 'смертность', 'от', 'рака', ',', 'сообщает', 'РИА', 'Новости', '.']
# Разметка: ['NOUN', 'ADP', 'ADJ', 'NOUN', 'PROPN', 'PROPN', 'VERB', 'PUNCT', 'ADP', 'DET', 'NOUN', 'PROPN', 'VERB', 'ADV', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'PUNCT', 'VERB', 'PROPN', 'PROPN', 'PUNCT']

# %%
X_all, y_all = [], []
for doc in docs:
    X, y = doc_to_data(doc)
    X_all.extend(X)
    y_all.extend(y)

# %% [markdown]
# ### Предикторы

# %%
def word_shape(word):
    return re.sub(r"[A-ZА-Я]", "X",
           re.sub(r"[a-zа-я]", "x",
           re.sub(r"[0-9]", "d", word)))

def word2features(sent, i):
    word = sent[i]
    features = {
        "bias": 1.0,
        "word.lower": word.lower(),
        "word[-3:]": word[-3:],
        "word[-2:]": word[-2:],
        "word[:2]": word[:2],
        "word[:3]": word[:3],
        "word.isupper": word.isupper(),
        "word.istitle": word.istitle(),
        "word.isdigit": word.isdigit(),
        "word.shape": word_shape(word),
    }
    if i > 0:
        prev = sent[i-1]
        features.update({
            "-1:word.lower": prev.lower(),
            "-1:word[-3:]": prev[-3:],
            "-1:word[-2:]": prev[-2:],
            "-1:word[:2]": prev[:2],
            "-1:word[:3]": prev[:3],
            "-1:word.istitle": prev.istitle(),
            "-1:word.isupper": prev.isupper(),
            "-1:word.shape": word_shape(prev),
        })
    else:
        features["BOS"] = True

    if i < len(sent)-1:
        nxt = sent[i+1]
        features.update({
            "+1:word.lower": nxt.lower(),
            "+1:word[-3:]": nxt[-3:],
            "+1:word[-2:]": nxt[-2:],
            "+1:word[:2]": nxt[:2],
            "+1:word[:3]": nxt[:3],
            "+1:word.istitle": nxt.istitle(),
            "+1:word.isupper": nxt.isupper(),
            "+1:word.shape": word_shape(nxt),
        })
    else:
        features["EOS"] = True

    return features

def sent2features(sent):
    return [word2features(sent, i) for i in range(len(sent))]

# %%
X_feats = []

for sent in tqdm(X_all, desc="Extracting features"):
    X_feats.append(sent2features(sent))
# Out:
# Extracting features:   0%|          | 0/23500 [00:00<?, ?it/s]

# %%
X_feats[0]
# Out:
# [{'bias': 1.0,
#   'word.lower': 'вице-премьер',
#   'word[-3:]': 'ьер',
#   'word[-2:]': 'ер',
#   'word[:2]': 'Ви',
#   'word[:3]': 'Виц',
#   'word.isupper': False,
#   'word.istitle': False,
#   'word.isdigit': False,
#   'word.shape': 'Xxxx-xxxxxxx',
#   'BOS': True,
#   '+1:word.lower': 'по',
#   '+1:word[-3:]': 'по',
#   '+1:word[-2:]': 'по',
#   '+1:word[:2]': 'по',
#   '+1:word[:3]': 'по',
#   '+1:word.istitle': False,
#   '+1:word.isupper': False,
#   '+1:word.shape': 'xx'},
#  {'bias': 1.0,
#   'word.lower': 'по',
#   'word[-3:]': 'по',
#   'word[-2:]': 'по',
#   'word[:2]': 'по',
#   'word[:3]': 'по',
#   'word.isupper': False,
#   'word.istitle': False,
#   'word.isdigit': False,
#   'word.shape': 'xx',
#   '-1:word.lower': 'вице-премьер',
#   '-1:word[-3:]': 'ьер',
#   '-1:word[-2:]': 'ер',
#   '-1:word[:2]': 'Ви',
#   '-1:word[:3]': 'Виц',
#   '-1:word.istitle': False,
#   '-1:word.isupper': False,
#   '-1:word.shape': 'Xxxx-xxxxxxx',
#   '+1:word.lower': 'социальным',
#   '+1:word[-3:]': 'ным',
#   '+1:word[-2:]': 'ым',
#   '+1:word[:2]': 'со',
#   '+1:word[:3]': 'соц',
#   '+1:word.istitle': False,
#   '+1:word.isupper': False,
#   '+1:word.shape': 'xxxxxxxxxx'},
#  {'bias': 1.0,
#   'word.lower': 'социальным',
#   'word[-3:]': 'ным',
#   'word[-2:]': 'ым',
#   'word[:2]': 'со',
#   'word[:3]': 'соц',
#   'word.isupper': False,
#   'word.istitle': False,
#   'word.isdigit': False,
#   'word.shape': 'xxxxxxxxxx',
#   '-1:word.lower': 'по',
#   '-1:word[-3:]': 'по',
#   '-1:word[-2:]': 'по',
#   '-1:word[:2]': 'по',
#   '-1:word[:3]': 'по',
#   '-1:word.istitle': False,
#   '-1:word.isupper': False,
#   '-1:word.shape': 'xx',
#   '+1:word.lower': 'вопросам',
#   '+1:word[-3:]': 'сам',
#   '+1:word[-2:]': 'ам',
#   '+1:word[:2]': 'во',
#   '+1:word[:3]': 'воп',
#   '+1:word.istitle': False,
#   '+1:word.isupper': False,
#   '+1:word.shape': 'xxxxxxxx'},
#  {'bias': 1.0,
#   'word.lower': 'вопросам',
#   'word[-3:]': 'сам',
#   'word[-2:]': 'ам',
#   'word[:2]': 'во',
#   'word[:3]': 'воп',
#   'word.isupper': False,
#   'word.istitle': False,
#   'word.isdigit': False,
#   'word.shape': 'xxxxxxxx',
#   '-1:word.lower': 'социальным',
#   '-1:word[-3:]': 'ным',
#   '-1:word[-2:]': 'ым',
#   '-1:word[:2]': 'со',
#   '-1:word[:3]': 'соц',
#   '-1:word.istitle': False,
#   '-1:word.isupper': False,
#   '-1:word.shape': 'xxxxxxxxxx',
#   '+1:word.lower': 'татьяна',
#   '+1:word[-3:]': 'яна',
#   '+1:word[-2:]': 'на',
#   '+1:word[:2]': 'Та',
#   '+1:word[:3]': 'Тат',
#   '+1:word.istitle': True,
#   '+1:word.isupper': False,
#   '+1:word.shape': 'Xxxxxxx'},
#  {'bias': 1.0,
#   'word.lower': 'татьяна',
#   'word[-3:]': 'яна',
#   'word[-2:]': 'на',
#   'word[:2]': 'Та',
#   'word[:3]': 'Тат',
#   'word.isupper': False,
#   'word.istitle': True,
#   'word.isdigit': False,
#   'word.shape': 'Xxxxxxx',
#   '-1:word.lower': 'вопросам',
#   '-1:word[-3:]': 'сам',
#   '-1:word[-2:]': 'ам',
#   '-1:word[:2]': 'во',
#   '-1:word[:3]': 'воп',
#   '-1:word.istitle': False,
#   '-1:word.isupper': False,
#   '-1:word.shape': 'xxxxxxxx',
#   '+1:word.lower': 'голикова',
#   '+1:word[-3:]': 'ова',
#   '+1:word[-2:]': 'ва',
#   '+1:word[:2]': 'Го',
#   '+1:word[:3]': 'Гол',
#   '+1:word.istitle': True,
#   '+1:word.isupper': False,
#   '+1:word.shape': 'Xxxxxxxx'},
#  {'bias': 1.0,
#   'word.lower': 'голикова',
#   'word[-3:]': 'ова',
#   'word[-2:]': 'ва',
#   'word[:2]': 'Го',
#   'word[:3]': 'Гол',
#   'word.isupper': False,
#   'word.istitle': True,
#   'word.isdigit': False,
#   'word.shape': 'Xxxxxxxx',
#   '-1:word.lower': 'татьяна',
#   '-1:word[-3:]': 'яна',
#   '-1:word[-2:]': 'на',
#   '-1:word[:2]': 'Та',
#   '-1:word[:3]': 'Тат',
#   '-1:word.istitle': True,
#   '-1:word.isupper': False,
#   '-1:word.shape': 'Xxxxxxx',
#   '+1:word.lower': 'рассказала',
#   '+1:word[-3:]': 'ала',
#   '+1:word[-2:]': 'ла',
#   '+1:word[:2]': 'ра',
#   '+1:word[:3]': 'рас',
#   '+1:word.istitle': False,
#   '+1:word.isupper': False,
#   '+1:word.shape': 'xxxxxxxxxx'},
#  {'bias': 1.0,
#   'word.lower': 'рассказала',
#   'word[-3:]': 'ала',
#   'word[-2:]': 'ла',
#   'word[:2]': 'ра',
#   'word[:3]': 'рас',
#   'word.isupper': False,
#   'word.istitle': False,
#   'word.isdigit': False,
#   'word.shape': 'xxxxxxxxxx',
#   '-1:word.lower': 'голикова',
#   '-1:word[-3:]': 'ова',
#   '-1:word[-2:]': 'ва',
#   '-1:word[:2]': 'Го',
#   '-1:word[:3]': 'Гол',
#   '-1:word.istitle': True,
#   '-1:word.isupper': False,
#   '-1:word.shape': 'Xxxxxxxx',
#   '+1:word.lower': ',',
#   '+1:word[-3:]': ',',
#   '+1:word[-2:]': ',',
#   '+1:word[:2]': ',',
#   '+1:word[:3]': ',',
#   '+1:word.istitle': False,
#   '+1:word.isupper': False,
#   '+1:word.shape': ','},
#  {'bias': 1.0,
#   'word.lower': ',',
#   'word[-3:]': ',',
#   'word[-2:]': ',',
#   'word[:2]': ',',
#   'word[:3]': ',',
#   'word.isupper': False,
#   'word.istitle': False,
#   'word.isdigit': False,
#   'word.shape': ',',
#   '-1:word.lower': 'рассказала',
#   '-1:word[-3:]': 'ала',
#   '-1:word[-2:]': 'ла',
#   '-1:word[:2]': 'ра',
#   '-1:word[:3]': 'рас',
#   '-1:word.istitle': False,
#   '-1:word.isupper': False,
#   '-1:word.shape': 'xxxxxxxxxx',
#   '+1:word.lower': 'в',
#   '+1:word[-3:]': 'в',
#   '+1:word[-2:]': 'в',
#   '+1:word[:2]': 'в',
#   '+1:word[:3]': 'в',
#   '+1:word.istitle': False,
#   '+1:word.isupper': False,
#   '+1:word.shape': 'x'},
#  {'bias': 1.0,
#   'word.lower': 'в',
#   'word[-3:]': 'в',
#   'word[-2:]': 'в',
#   'word[:2]': 'в',
#   'word[:3]': 'в',
#   'word.isupper': False,
#   'word.istitle': False,
#   'word.isdigit': False,
#   'word.shape': 'x',
#   '-1:word.lower': ',',
#   '-1:word[-3:]': ',',
#   '-1:word[-2:]': ',',
#   '-1:word[:2]': ',',
#   '-1:word[:3]': ',',
#   '-1:word.istitle': False,
#   '-1:word.isupper': False,
#   '-1:word.shape': ',',
#   '+1:word.lower': 'каких',
#   '+1:word[-3:]': 'ких',
#   '+1:word[-2:]': 'их',
#   '+1:word[:2]': 'ка',
#   '+1:word[:3]': 'как',
#   '+1:word.istitle': False,
#   '+1:word.isupper': False,
#   '+1:word.shape': 'xxxxx'},
#  {'bias': 1.0,
#   'word.lower': 'каких',
#   'word[-3:]': 'ких',
#   'word[-2:]': 'их',
#   'word[:2]': 'ка',
#   'word[:3]': 'как',
#   'word.isupper': False,
#   'word.istitle': False,
#   'word.isdigit': False,
#   'word.shape': 'xxxxx',
#   '-1:word.lower': 'в',
#   '-1:word[-3:]': 'в',
#   '-1:word[-2:]': 'в',
#   '-1:word[:2]': 'в',
#   '-1:word[:3]': 'в',
#   '-1:word.istitle': False,
#   '-1:word.isupper': False,
#   '-1:word.shape': 'x',
#   '+1:word.lower': 'регионах',
#   '+1:word[-3:]': 'нах',
#   '+1:word[-2:]': 'ах',
#   '+1:word[:2]': 'ре',
#   '+1:word[:3]': 'рег',
#   '+1:word.istitle': False,
#   '+1:word.isupper': False,
#   '+1:word.shape': 'xxxxxxxx'},
#  {'bias': 1.0,
#   'word.lower': 'регионах',
#   'word[-3:]': 'нах',
#   'word[-2:]': 'ах',
#   'word[:2]': 'ре',
#   'word[:3]': 'рег',
#   'word.isupper': False,
#   'word.istitle': False,
#   'word.isdigit': False,
#   'word.shape': 'xxxxxxxx',
#   '-1:word.lower': 'каких',
#   '-1:word[-3:]': 'ких',
#   '-1:word[-2:]': 'их',
#   '-1:word[:2]': 'ка',
#   '-1:word[:3]': 'как',
#   '-1:word.istitle': False,
#   '-1:word.isupper': False,
#   '-1:word.shape': 'xxxxx',
#   '+1:word.lower': 'россии',
#   '+1:word[-3:]': 'сии',
#   '+1:word[-2:]': 'ии',
#   '+1:word[:2]': 'Ро',
#   '+1:word[:3]': 'Рос',
#   '+1:word.istitle': True,
#   '+1:word.isupper': False,
#   '+1:word.shape': 'Xxxxxx'},
#  {'bias': 1.0,
#   'word.lower': 'россии',
#   'word[-3:]': 'сии',
#   'word[-2:]': 'ии',
#   'word[:2]': 'Ро',
#   'word[:3]': 'Рос',
#   'word.isupper': False,
#   'word.istitle': True,
#   'word.isdigit': False,
#   'word.shape': 'Xxxxxx',
#   '-1:word.lower': 'регионах',
#   '-1:word[-3:]': 'нах',
#   '-1:word[-2:]': 'ах',
#   '-1:word[:2]': 'ре',
#   '-1:word[:3]': 'рег',
#   '-1:word.istitle': False,
#   '-1:word.isupper': False,
#   '-1:word.shape': 'xxxxxxxx',
#   '+1:word.lower': 'зафиксирована',
#   '+1:word[-3:]': 'ана',
#   '+1:word[-2:]': 'на',
#   '+1:word[:2]': 'за',
#   '+1:word[:3]': 'заф',
#   '+1:word.istitle': False,
#   '+1:word.isupper': False,
#   '+1:word.shape': 'xxxxxxxxxxxxx'},
#  {'bias': 1.0,
#   'word.lower': 'зафиксирована',
#   'word[-3:]': 'ана',
#   'word[-2:]': 'на',
#   'word[:2]': 'за',
#   'word[:3]': 'заф',
#   'word.isupper': False,
#   'word.istitle': False,
#   'word.isdigit': False,
#   'word.shape': 'xxxxxxxxxxxxx',
#   '-1:word.lower': 'россии',
#   '-1:word[-3:]': 'сии',
#   '-1:word[-2:]': 'ии',
#   '-1:word[:2]': 'Ро',
#   '-1:word[:3]': 'Рос',
#   '-1:word.istitle': True,
#   '-1:word.isupper': False,
#   '-1:word.shape': 'Xxxxxx',
#   '+1:word.lower': 'наиболее',
#   '+1:word[-3:]': 'лее',
#   '+1:word[-2:]': 'ее',
#   '+1:word[:2]': 'на',
#   '+1:word[:3]': 'наи',
#   '+1:word.istitle': False,
#   '+1:word.isupper': False,
#   '+1:word.shape': 'xxxxxxxx'},
#  {'bias': 1.0,
#   'word.lower': 'наиболее',
#   'word[-3:]': 'лее',
#   'word[-2:]': 'ее',
#   'word[:2]': 'на',
#   'word[:3]': 'наи',
#   'word.isupper': False,
#   'word.istitle': False,
#   'word.isdigit': False,
#   'word.shape': 'xxxxxxxx',
#   '-1:word.lower': 'зафиксирована',
#   '-1:word[-3:]': 'ана',
#   '-1:word[-2:]': 'на',
#   '-1:word[:2]': 'за',
#   '-1:word[:3]': 'заф',
#   '-1:word.istitle': False,
#   '-1:word.isupper': False,
#   '-1:word.shape': 'xxxxxxxxxxxxx',
#   '+1:word.lower': 'высокая',
#   '+1:word[-3:]': 'кая',
#   '+1:word[-2:]': 'ая',
#   '+1:word[:2]': 'вы',
#   '+1:word[:3]': 'выс',
#   '+1:word.istitle': False,
#   '+1:word.isupper': False,
#   '+1:word.shape': 'xxxxxxx'},
#  {'bias': 1.0,
#   'word.lower': 'высокая',
#   'word[-3:]': 'кая',
#   'word[-2:]': 'ая',
#   'word[:2]': 'вы',
#   'word[:3]': 'выс',
#   'word.isupper': False,
#   'word.istitle': False,
#   'word.isdigit': False,
#   'word.shape': 'xxxxxxx',
#   '-1:word.lower': 'наиболее',
#   '-1:word[-3:]': 'лее',
#   '-1:word[-2:]': 'ее',
#   '-1:word[:2]': 'на',
#   '-1:word[:3]': 'наи',
#   '-1:word.istitle': False,
#   '-1:word.isupper': False,
#   '-1:word.shape': 'xxxxxxxx',
#   '+1:word.lower': 'смертность',
#   '+1:word[-3:]': 'сть',
#   '+1:word[-2:]': 'ть',
#   '+1:word[:2]': 'см',
#   '+1:word[:3]': 'сме',
#   '+1:word.istitle': False,
#   '+1:word.isupper': False,
#   '+1:word.shape': 'xxxxxxxxxx'},
#  {'bias': 1.0,
#   'word.lower': 'смертность',
#   'word[-3:]': 'сть',
#   'word[-2:]': 'ть',
#   'word[:2]': 'см',
#   'word[:3]': 'сме',
#   'word.isupper': False,
#   'word.istitle': False,
#   'word.isdigit': False,
#   'word.shape': 'xxxxxxxxxx',
#   '-1:word.lower': 'высокая',
#   '-1:word[-3:]': 'кая',
#   '-1:word[-2:]': 'ая',
#   '-1:word[:2]': 'вы',
#   '-1:word[:3]': 'выс',
#   '-1:word.istitle': False,
#   '-1:word.isupper': False,
#   '-1:word.shape': 'xxxxxxx',
#   '+1:word.lower': 'от',
#   '+1:word[-3:]': 'от',
#   '+1:word[-2:]': 'от',
#   '+1:word[:2]': 'от',
#   '+1:word[:3]': 'от',
#   '+1:word.istitle': False,
#   '+1:word.isupper': False,
#   '+1:word.shape': 'xx'},
#  {'bias': 1.0,
#   'word.lower': 'от',
#   'word[-3:]': 'от',
#   'word[-2:]': 'от',
#   'word[:2]': 'от',
#   'word[:3]': 'от',
#   'word.isupper': False,
#   'word.istitle': False,
#   'word.isdigit': False,
#   'word.shape': 'xx',
#   '-1:word.lower': 'смертность',
#   '-1:word[-3:]': 'сть',
#   '-1:word[-2:]': 'ть',
#   '-1:word[:2]': 'см',
#   '-1:word[:3]': 'сме',
#   '-1:word.istitle': False,
#   '-1:word.isupper': False,
#   '-1:word.shape': 'xxxxxxxxxx',
#   '+1:word.lower': 'рака',
#   '+1:word[-3:]': 'ака',
#   '+1:word[-2:]': 'ка',
#   '+1:word[:2]': 'ра',
#   '+1:word[:3]': 'рак',
#   '+1:word.istitle': False,
#   '+1:word.isupper': False,
#   '+1:word.shape': 'xxxx'},
#  {'bias': 1.0,
#   'word.lower': 'рака',
#   'word[-3:]': 'ака',
#   'word[-2:]': 'ка',
#   'word[:2]': 'ра',
#   'word[:3]': 'рак',
#   'word.isupper': False,
#   'word.istitle': False,
#   'word.isdigit': False,
#   'word.shape': 'xxxx',
#   '-1:word.lower': 'от',
#   '-1:word[-3:]': 'от',
#   '-1:word[-2:]': 'от',
#   '-1:word[:2]': 'от',
#   '-1:word[:3]': 'от',
#   '-1:word.istitle': False,
#   '-1:word.isupper': False,
#   '-1:word.shape': 'xx',
#   '+1:word.lower': ',',
#   '+1:word[-3:]': ',',
#   '+1:word[-2:]': ',',
#   '+1:word[:2]': ',',
#   '+1:word[:3]': ',',
#   '+1:word.istitle': False,
#   '+1:word.isupper': False,
#   '+1:word.shape': ','},
#  {'bias': 1.0,
#   'word.lower': ',',
#   'word[-3:]': ',',
#   'word[-2:]': ',',
#   'word[:2]': ',',
#   'word[:3]': ',',
#   'word.isupper': False,
#   'word.istitle': False,
#   'word.isdigit': False,
#   'word.shape': ',',
#   '-1:word.lower': 'рака',
#   '-1:word[-3:]': 'ака',
#   '-1:word[-2:]': 'ка',
#   '-1:word[:2]': 'ра',
#   '-1:word[:3]': 'рак',
#   '-1:word.istitle': False,
#   '-1:word.isupper': False,
#   '-1:word.shape': 'xxxx',
#   '+1:word.lower': 'сообщает',
#   '+1:word[-3:]': 'ает',
#   '+1:word[-2:]': 'ет',
#   '+1:word[:2]': 'со',
#   '+1:word[:3]': 'соо',
#   '+1:word.istitle': False,
#   '+1:word.isupper': False,
#   '+1:word.shape': 'xxxxxxxx'},
#  {'bias': 1.0,
#   'word.lower': 'сообщает',
#   'word[-3:]': 'ает',
#   'word[-2:]': 'ет',
#   'word[:2]': 'со',
#   'word[:3]': 'соо',
#   'word.isupper': False,
#   'word.istitle': False,
#   'word.isdigit': False,
#   'word.shape': 'xxxxxxxx',
#   '-1:word.lower': ',',
#   '-1:word[-3:]': ',',
#   '-1:word[-2:]': ',',
#   '-1:word[:2]': ',',
#   '-1:word[:3]': ',',
#   '-1:word.istitle': False,
#   '-1:word.isupper': False,
#   '-1:word.shape': ',',
#   '+1:word.lower': 'риа',
#   '+1:word[-3:]': 'РИА',
#   '+1:word[-2:]': 'ИА',
#   '+1:word[:2]': 'РИ',
#   '+1:word[:3]': 'РИА',
#   '+1:word.istitle': False,
#   '+1:word.isupper': True,
#   '+1:word.shape': 'XXX'},
#  {'bias': 1.0,
#   'word.lower': 'риа',
#   'word[-3:]': 'РИА',
#   'word[-2:]': 'ИА',
#   'word[:2]': 'РИ',
#   'word[:3]': 'РИА',
#   'word.isupper': True,
#   'word.istitle': False,
#   'word.isdigit': False,
#   'word.shape': 'XXX',
#   '-1:word.lower': 'сообщает',
#   '-1:word[-3:]': 'ает',
#   '-1:word[-2:]': 'ет',
#   '-1:word[:2]': 'со',
#   '-1:word[:3]': 'соо',
#   '-1:word.istitle': False,
#   '-1:word.isupper': False,
#   '-1:word.shape': 'xxxxxxxx',
#   '+1:word.lower': 'новости',
#   '+1:word[-3:]': 'сти',
#   '+1:word[-2:]': 'ти',
#   '+1:word[:2]': 'Но',
#   '+1:word[:3]': 'Нов',
#   '+1:word.istitle': True,
#   '+1:word.isupper': False,
#   '+1:word.shape': 'Xxxxxxx'},
#  {'bias': 1.0,
#   'word.lower': 'новости',
#   'word[-3:]': 'сти',
#   'word[-2:]': 'ти',
#   'word[:2]': 'Но',
#   'word[:3]': 'Нов',
#   'word.isupper': False,
#   'word.istitle': True,
#   'word.isdigit': False,
#   'word.shape': 'Xxxxxxx',
#   '-1:word.lower': 'риа',
#   '-1:word[-3:]': 'РИА',
#   '-1:word[-2:]': 'ИА',
#   '-1:word[:2]': 'РИ',
#   '-1:word[:3]': 'РИА',
#   '-1:word.istitle': False,
#   '-1:word.isupper': True,
#   '-1:word.shape': 'XXX',
#   '+1:word.lower': '.',
#   '+1:word[-3:]': '.',
#   '+1:word[-2:]': '.',
#   '+1:word[:2]': '.',
#   '+1:word[:3]': '.',
#   '+1:word.istitle': False,
#   '+1:word.isupper': False,
#   '+1:word.shape': '.'},
#  {'bias': 1.0,
#   'word.lower': '.',
#   'word[-3:]': '.',
#   'word[-2:]': '.',
#   'word[:2]': '.',
#   'word[:3]': '.',
#   'word.isupper': False,
#   'word.istitle': False,
#   'word.isdigit': False,
#   'word.shape': '.',
#   '-1:word.lower': 'новости',
#   '-1:word[-3:]': 'сти',
#   '-1:word[-2:]': 'ти',
#   '-1:word[:2]': 'Но',
#   '-1:word[:3]': 'Нов',
#   '-1:word.istitle': True,
#   '-1:word.isupper': False,
#   '-1:word.shape': 'Xxxxxxx',
#   'EOS': True}]

# %% [markdown]
# ### Разбиение на train и test

# %%
X_train, X_test, y_train, y_test = train_test_split(X_feats, y_all, test_size=0.1, random_state=42)

# %% [markdown]
# ### Обучение CRF

# %%
crf = CRF(
    all_possible_transitions=True
)
crf.fit(X_train, y_train)
# Out:
# CRF(all_possible_transitions=True)

# %% [markdown]
# ### Метрики на тесте

# %%
y_pred = crf.predict(X_test)
print(metrics.flat_classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          ADJ       0.95      0.97      0.96      3735
#          ADP       1.00      1.00      1.00      4974
#          ADV       0.97      0.94      0.95      1048
#          AUX       0.93      0.96      0.95       309
#        CCONJ       0.98      1.00      0.99      1016
#          DET       0.95      0.95      0.95       658
#         NOUN       0.98      0.98      0.98     11745
#          NUM       0.97      0.95      0.96       806
#         PART       0.98      0.95      0.96       532
#         PRON       0.98      0.97      0.97      1527
#        PROPN       0.96      0.97      0.97      3176
#        PUNCT       1.00      1.00      1.00      7631
#        SCONJ       0.96      0.99      0.97       733
#          SYM       0.90      1.00      0.95         9
#         VERB       0.98      0.97      0.97      4938
#            X       0.94      0.86      0.90       392
#
#     accuracy                           0.98     43229
#    macro avg       0.96      0.97      0.97     43229
# weighted avg       0.98      0.98      0.98     43229

# %% [markdown]
# ### Примеры работы на омонимах

# %%
def tag_sentence(text, crf_model):
    tokens = [t.text for t in tokenize(text)]
    feats = sent2features(tokens)
    tags = crf_model.predict_single(feats)
    return list(zip(tokens, tags))

# %%
tag_sentence("Штирлиц открыл окно. Из окна дуло. Штирлиц закрыл окно, и дуло исчезло.", crf)
# Out:
# [('Штирлиц', 'NOUN'),
#  ('открыл', 'VERB'),
#  ('окно', 'NOUN'),
#  ('.', 'PUNCT'),
#  ('Из', 'ADP'),
#  ('окна', 'NOUN'),
#  ('дуло', 'VERB'),
#  ('.', 'PUNCT'),
#  ('Штирлиц', 'PROPN'),
#  ('закрыл', 'VERB'),
#  ('окно', 'NOUN'),
#  (',', 'PUNCT'),
#  ('и', 'CCONJ'),
#  ('дуло', 'NOUN'),
#  ('исчезло', 'VERB'),
#  ('.', 'PUNCT')]

# %%
tag_sentence("По стене ползет кирпич, оловянный как стекло, ну и пусть себе летит, нам не нужен пенопласт.", crf)
# Out:
# [('По', 'ADP'),
#  ('стене', 'NOUN'),
#  ('ползет', 'VERB'),
#  ('кирпич', 'NOUN'),
#  (',', 'PUNCT'),
#  ('оловянный', 'ADJ'),
#  ('как', 'SCONJ'),
#  ('стекло', 'NOUN'),
#  (',', 'PUNCT'),
#  ('ну', 'PART'),
#  ('и', 'CCONJ'),
#  ('пусть', 'PART'),
#  ('себе', 'PRON'),
#  ('летит', 'VERB'),
#  (',', 'PUNCT'),
#  ('нам', 'PRON'),
#  ('не', 'PART'),
#  ('нужен', 'ADJ'),
#  ('пенопласт', 'NOUN'),
#  ('.', 'PUNCT')]

# %%
tag_sentence("Необходимо организовать сбор бумаги, стекла и пластика с повторной сортировкой на свалке.", crf)
# Out:
# [('Необходимо', 'ADJ'),
#  ('организовать', 'VERB'),
#  ('сбор', 'NOUN'),
#  ('бумаги', 'NOUN'),
#  (',', 'PUNCT'),
#  ('стекла', 'NOUN'),
#  ('и', 'CCONJ'),
#  ('пластика', 'NOUN'),
#  ('с', 'ADP'),
#  ('повторной', 'ADJ'),
#  ('сортировкой', 'NOUN'),
#  ('на', 'ADP'),
#  ('свалке', 'NOUN'),
#  ('.', 'PUNCT')]

# %%
tag_sentence("Стол пошатнулся, стакан разбился, и вода моментально стекла на пол.", crf)
# Out:
# [('Стол', 'NOUN'),
#  ('пошатнулся', 'VERB'),
#  (',', 'PUNCT'),
#  ('стакан', 'NOUN'),
#  ('разбился', 'VERB'),
#  (',', 'PUNCT'),
#  ('и', 'CCONJ'),
#  ('вода', 'NOUN'),
#  ('моментально', 'ADV'),
#  ('стекла', 'VERB'),
#  ('на', 'ADP'),
#  ('пол', 'NOUN'),
#  ('.', 'PUNCT')]

# %%
tag_sentence("Печь совсем остыла, и в доме стало холодно.", crf)
# Out:
# [('Печь', 'NOUN'),
#  ('совсем', 'ADV'),
#  ('остыла', 'VERB'),
#  (',', 'PUNCT'),
#  ('и', 'CCONJ'),
#  ('в', 'ADP'),
#  ('доме', 'NOUN'),
#  ('стало', 'VERB'),
#  ('холодно', 'ADJ'),
#  ('.', 'PUNCT')]

# %%
tag_sentence("В эту субботу мы хотим снова печь пироги с яблоками.", crf)
# Out:
# [('В', 'ADP'),
#  ('эту', 'DET'),
#  ('субботу', 'NOUN'),
#  ('мы', 'PRON'),
#  ('хотим', 'VERB'),
#  ('снова', 'ADV'),
#  ('печь', 'VERB'),
#  ('пироги', 'NOUN'),
#  ('с', 'ADP'),
#  ('яблоками', 'NOUN'),
#  ('.', 'PUNCT')]
